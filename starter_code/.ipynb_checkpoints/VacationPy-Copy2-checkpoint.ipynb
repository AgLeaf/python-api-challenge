# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\micha\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\micha\anaconda3\lib\site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import csv
import json

# Import API key
from api_keys import g_key
from api_keys import weather_api_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
cities_csv = os.path.join('..', 'output_data', 'city_list.csv')
cityWeather_df = pd.read_csv(cities_csv)
cityWeather_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     La Ronge  55.1001 -105.2842     34.05        75          75       10.36
# 1       Albany  42.6001  -73.9662     55.58        68         100        1.01
# 2  Zhangjiakou  40.8100  114.8794     39.24        43           0        2.21
# 3       Basoko   1.2391   23.6160     71.22        88          20        3.42
# 4        Vaini -21.2000 -175.2000     73.56        78          20        8.05
#
#   Country        Date
# 0      CA  1634932668
# 1      US  1634932668
# 2      CN  1634932668
# 3      CD  1634932669
# 4      TO  1634932669

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
gmaps.configure(api_key=g_key)

# %%
# Store 'Lat' and 'Lng' into  locations 
locations = cityWeather_df[["Lat", "Lng"]].astype(float)

# Convert Humidity to float and store
# HINT: be sure to handle NaN values
#cityWeather_df = cityWeather_df.dropna()
humidityHeatmap = cityWeather_df["Humidity"].astype(float)

# %%
# Create a Humidity Heatmap layer
fig = gmaps.figure(center=(50.0, -35.0), zoom_level=2)

heat_layer = gmaps.heatmap_layer(locations, weights=humidityHeatmap, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 1)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
# A max temperature lower than 80 degrees but higher than 70.
# Wind speed less than 10 mph.
# Zero cloudiness.
# Drop any rows that don't contain all three conditions. You want to be sure the weather is ideal.
reduced_cities_df = cityWeather_df.loc[(cityWeather_df["Wind Speed"] < 10) & (cityWeather_df["Cloudiness"] == 0) & \
                                   (cityWeather_df["Max Temp"] > 70) & (cityWeather_df["Max Temp"] < 80)].dropna()
reduced_cities_df
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 71          Turbat  26.0023   63.0440     76.41        17           0
# 100           Jalu  29.0331   21.5482     73.45        35           0
# 101   Saint-Pierre -21.3393   55.4781     72.93        83           0
# 158        Bānkura  23.2500   87.0667     72.77        70           0
# 164        Baghdad  33.3406   44.4009     71.51        28           0
# 177          Balad  34.0164   44.1453     73.13        21           0
# 190        Russell  32.3502  -85.1999     77.70        55           0
# 274     Kiryat Gat  31.6100   34.7642     70.72        67           0
# 286       Eldorado -23.7869  -54.2836     79.30        59           0
# 371     Djebeniana  35.0350   10.9081     73.20        77           0
# 536       Dzaoudzi -12.7887   45.2699     75.09        83           0
# 560  Alice Springs -23.7000  133.8833     72.95        27           0
#
#      Wind Speed Country        Date
# 71         7.52      PK  1634932688
# 100        9.04      LY  1634932645
# 101        4.61      RE  1634932697
# 158        4.29      IN  1634932714
# 164        5.75      IQ  1634932716
# 177        9.44      IQ  1634932719
# 190        8.55      US  1634932724
# 274        7.38      IL  1634932750
# 286        5.26      BR  1634932754
# 371        8.12      TN  1634932780
# 536        3.44      YT  1634932842
# 560        8.05      AU  1634932681

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
reduced_cities_df["Hotel Name"] = ""
reduced_cities_df.head()
# Out:
#              City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 71         Turbat  26.0023  63.0440     76.41        17           0
# 100          Jalu  29.0331  21.5482     73.45        35           0
# 101  Saint-Pierre -21.3393  55.4781     72.93        83           0
# 158       Bānkura  23.2500  87.0667     72.77        70           0
# 164       Baghdad  33.3406  44.4009     71.51        28           0
#
#      Wind Speed Country        Date Hotel Name
# 71         7.52      PK  1634932688
# 100        9.04      LY  1634932645
# 101        4.61      RE  1634932697
# 158        4.29      IN  1634932714
# 164        5.75      IQ  1634932716

# %%
hotel_df = reduced_cities_df
hotel_df
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 71          Turbat  26.0023   63.0440     76.41        17           0
# 100           Jalu  29.0331   21.5482     73.45        35           0
# 101   Saint-Pierre -21.3393   55.4781     72.93        83           0
# 158        Bānkura  23.2500   87.0667     72.77        70           0
# 164        Baghdad  33.3406   44.4009     71.51        28           0
# 177          Balad  34.0164   44.1453     73.13        21           0
# 190        Russell  32.3502  -85.1999     77.70        55           0
# 274     Kiryat Gat  31.6100   34.7642     70.72        67           0
# 286       Eldorado -23.7869  -54.2836     79.30        59           0
# 371     Djebeniana  35.0350   10.9081     73.20        77           0
# 536       Dzaoudzi -12.7887   45.2699     75.09        83           0
# 560  Alice Springs -23.7000  133.8833     72.95        27           0
#
#      Wind Speed Country        Date Hotel Name
# 71         7.52      PK  1634932688
# 100        9.04      LY  1634932645
# 101        4.61      RE  1634932697
# 158        4.29      IN  1634932714
# 164        5.75      IQ  1634932716
# 177        9.44      IQ  1634932719
# 190        8.55      US  1634932724
# 274        7.38      IL  1634932750
# 286        5.26      BR  1634932754
# 371        8.12      TN  1634932780
# 536        3.44      YT  1634932842
# 560        8.05      AU  1634932681

# %%
# params dictionary to update each iteration
params = {
    "radius": 5000,
    "types": "lodging",
    "key": g_key
}

# Use the lat/lng we recovered to identify airports
for index, row in hotel_df.iterrows():
    # get lat, lng from df
    lat = row["Lat"]
    lng = row["Lng"]

    # change location each iteration while leaving original params in place
    params["location"] = f"{lat},{lng}"

    # Use the search term: "International Airport" and our lat/lng
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # make request and print url
    name_address = requests.get(base_url, params=params)
    
#     print the name_address url, avoid doing for public github repos in order to avoid exposing key
#     print(name_address.url)

    # convert to json
    name_address = name_address.json()
    print(json.dumps(name_address, indent=4, sort_keys=True))

    # Since some data may be missing we incorporate a try-except to skip any that are missing a data point.
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["results"][0]["name"]
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "Aap_uEDLFlhVDNALEz_a-FzPAcHnssp795dhudsGJ2rBdGEwrBZVg6UH1X6Y9zQ18te1drYoT4YwQOxHNhT3S8PhujwI5mBLEjAEpvx7SZK4dwzJcqWi0_7-ZGgL8l_eSIKDLNpZgPLiRMrhQtQe31S-aIk5bpG7qxig63iLEOPlcGnAjGtvXt5AzuPd2DwDMA9lFZPHrzgGQtze4R303DOC1g1I_BfrkZp_NfwMdLTv3lsP_FcPdd9O23X7ONsxvIeh5_2EhgP9fGa-RKyAsFHlv0HClhVYqDm0HS9PfZGKsEfEHvfnRiJ6dHm0SGohT9MQikachBq-rfiqAqaRTlLX36j2_IMRiabl5kjzu-h-zhjQdCgfzGR2ooVp1CgG_GQv0thUUmsM75PAtWX_dSH6zWoBTzPI3d7oj6r3m0Rp_TCyT_lSXi-kS5Q_",
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 26.002385,
#                     "lng": 63.0437939
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 26.0035951302915,
#                         "lng": 63.0451702302915
#                     },
#                     "southwest": {
#                         "lat": 26.0008971697085,
#                         "lng": 63.04247226970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Mubashar Quarters",
#             "place_id": "ChIJv6BZawNZxz4Rp3MPj4fH7u8",
#             "plus_code": {
#                 "compound_code": "222V+XG Turbat, Pakistan",
#                 "global_code": "7JR5222V+XG"
#             },
#             "reference": "ChIJv6BZawNZxz4Rp3MPj4fH7u8",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Mubashar Residential Quarters, Turbat Bazaar, Malikabad Turbat, Turbat"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 26.0028453,
#                     "lng": 63.0442621
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 26.0041952302915,
#                         "lng": 63.04564813029151
#                     },
#                     "southwest": {
#                         "lat": 26.00149726970849,
#                         "lng": 63.0429501697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Baloch Kampan",
#             "place_id": "ChIJB9KKn65Zxz4RUX2Q4G7bROA",
#             "plus_code": {
#                 "compound_code": "223V+4P Turbat, Pakistan",
#                 "global_code": "7JR5223V+4P"
#             },
#             "reference": "ChIJB9KKn65Zxz4RUX2Q4G7bROA",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Malikabad Turbat, Turbat"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 26.0073232,
#                     "lng": 63.04635519999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 26.0087589802915,
#                         "lng": 63.0476354302915
#                     },
#                     "southwest": {
#                         "lat": 26.0060610197085,
#                         "lng": 63.04493746970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Lala Bashir Quarters",
#             "place_id": "ChIJXQr7pWlYxz4RORem8otbEBY",
#             "rating": 2,
#             "reference": "ChIJXQr7pWlYxz4RORem8otbEBY",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "224W+WGH, Turbat"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 26.0080546,
#                     "lng": 63.03830589999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 26.0094035802915,
#                         "lng": 63.0396548802915
#                     },
#                     "southwest": {
#                         "lat": 26.0067056197085,
#                         "lng": 63.03695691970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "BOQ's",
#             "place_id": "ChIJpWqxq4VZxz4Rt9NipPlWQkM",
#             "reference": "ChIJpWqxq4VZxz4Rt9NipPlWQkM",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "225Q+68F, Turbat"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 26.00526219999999,
#                     "lng": 63.0524727
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 26.0066005302915,
#                         "lng": 63.0538205802915
#                     },
#                     "southwest": {
#                         "lat": 26.0039025697085,
#                         "lng": 63.05112261970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Mazdoor Market",
#             "place_id": "ChIJo07k12VYxz4RkMmud6rT1tU",
#             "rating": 4.4,
#             "reference": "ChIJo07k12VYxz4RkMmud6rT1tU",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 7,
#             "vicinity": "2342+4X5, Turbat"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 26.0112983,
#                     "lng": 63.0475933
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 26.0126282302915,
#                         "lng": 63.04904028029151
#                     },
#                     "southwest": {
#                         "lat": 26.00993026970849,
#                         "lng": 63.0463423197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Majid Reiki House",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2048,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113389079444918936262\">Majid Baloch</a>"
#                     ],
#                     "photo_reference": "Aap_uECuCfcPRVqFuyJ-zrzyOJyW1UZf8gcZ1P5_qbCeVhFl2m0YBYciJF6Ora1ucXSvDqZQVWChkPEE84zRh8CZhbiVTTM_eeelaTxSlsQUQLFdivDlPbHxzEbYe5d_8ob9m3MgNQOnvkFRAC58ReJ3sbpKjtvc7vexK2KIKw2gL1DzffX_",
#                     "width": 948
#                 }
#             ],
#             "place_id": "ChIJVVFAEX9Zxz4RwuguZry33SA",
#             "plus_code": {
#                 "compound_code": "226X+G2 Turbat, Pakistan",
#                 "global_code": "7JR5226X+G2"
#             },
#             "reference": "ChIJVVFAEX9Zxz4RwuguZry33SA",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Unnamed Road, Turbat"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 25.9930287,
#                     "lng": 63.0483444
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 25.99436438029151,
#                         "lng": 63.0496580302915
#                     },
#                     "southwest": {
#                         "lat": 25.9916664197085,
#                         "lng": 63.0469600697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Fahid asghar",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "place_id": "ChIJhUYxMD5Zxz4RTU-0N-NugAg",
#             "plus_code": {
#                 "compound_code": "X2VX+68 Turbat, Pakistan",
#                 "global_code": "7JQ5X2VX+68"
#             },
#             "reference": "ChIJhUYxMD5Zxz4RTU-0N-NugAg",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Unnamed Road, Overseas Housing Scheme, Turbat"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 26.0057973,
#                     "lng": 63.05491070000001
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 26.0071233302915,
#                         "lng": 63.0561459302915
#                     },
#                     "southwest": {
#                         "lat": 26.0044253697085,
#                         "lng": 63.05344796970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Mulla Jan Hotel",
#             "place_id": "ChIJBQv5HWRYxz4Rg338ENgA2XI",
#             "rating": 3.2,
#             "reference": "ChIJBQv5HWRYxz4Rg338ENgA2XI",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 10,
#             "vicinity": "2343+8X7, Turbat"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 26.0056216,
#                     "lng": 63.0557634
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 26.0068720802915,
#                         "lng": 63.0571086302915
#                     },
#                     "southwest": {
#                         "lat": 26.0041741197085,
#                         "lng": 63.05441066970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Azad mobile communication",
#             "place_id": "ChIJuRB5PJ5Zxz4RW3Ng2KvMPYA",
#             "plus_code": {
#                 "compound_code": "2344+68 Turbat, Pakistan",
#                 "global_code": "7JR52344+68"
#             },
#             "reference": "ChIJuRB5PJ5Zxz4RW3Ng2KvMPYA",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Azad Dasht Coach Service, Main Road, Turbat"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 25.9978845,
#                     "lng": 63.0560607
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 25.9992379802915,
#                         "lng": 63.0572684802915
#                     },
#                     "southwest": {
#                         "lat": 25.9965400197085,
#                         "lng": 63.05457051970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Degree College Hostel 1",
#             "place_id": "ChIJ5QrHf3xYxz4R4B1dmoEO3W0",
#             "plus_code": {
#                 "compound_code": "X3X4+5C Turbat, Pakistan",
#                 "global_code": "7JQ5X3X4+5C"
#             },
#             "rating": 5,
#             "reference": "ChIJ5QrHf3xYxz4R4B1dmoEO3W0",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 3,
#             "vicinity": "Pasni Road, Turbat"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 26.0075608,
#                     "lng": 63.05594569999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 26.0089939302915,
#                         "lng": 63.0572796302915
#                     },
#                     "southwest": {
#                         "lat": 26.00629596970849,
#                         "lng": 63.05458166970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Muslim Hotel \u0645\u0633\u0644\u0645 \u06c1\u0648\u0679\u0644",
#             "place_id": "ChIJU-9LNWFYxz4RKfqj2KukvBE",
#             "rating": 3.8,
#             "reference": "ChIJU-9LNWFYxz4RKfqj2KukvBE",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 9,
#             "vicinity": "2354+29G, Turbat"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 25.9961859,
#                     "lng": 63.0565207
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 25.99720288029151,
#                         "lng": 63.05780963029149
#                     },
#                     "southwest": {
#                         "lat": 25.9945049197085,
#                         "lng": 63.05511166970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Degree College Hostel 2",
#             "photos": [
#                 {
#                     "height": 395,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110160856896812208710\">Mirwan Marri</a>"
#                     ],
#                     "photo_reference": "Aap_uEBhFWSPJFiuR9AnCD4RxJ4VwNfSsnV7tEkx2G5vwyKbfiFo4nGBqFDW99DTRTQe7GW16JzI4lAIJSgvQNc2lEGPRFOuVRPWlIYwTd3Ocn44nmyVCBEDORtUABzms0Q8ESy_VWsIJLyNBvg5yqoHojw0sgJQgIbDPie1azpTvMjt8LrB",
#                     "width": 712
#                 }
#             ],
#             "place_id": "ChIJNWQkCXxYxz4Ro1OZ5tvPCDk",
#             "rating": 3.2,
#             "reference": "ChIJNWQkCXxYxz4Ro1OZ5tvPCDk",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 17,
#             "vicinity": "X3W4+FJC, Turbat"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 26.0055943,
#                     "lng": 63.05827379999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 26.0068437802915,
#                         "lng": 63.0596221302915
#                     },
#                     "southwest": {
#                         "lat": 26.0041458197085,
#                         "lng": 63.05692416970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Shapur Hotel",
#             "photos": [
#                 {
#                     "height": 3456,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101614997248983383928\">Bezanjo Bezanjo</a>"
#                     ],
#                     "photo_reference": "Aap_uED4tOpFsonzv57ezEPFbwMbcGHJPcrEL7hnJ-urE34K98KvDFl2XbKsZrgVJv3CbTg1cD4Tq6Xw6BYKK7FFG54VZT3bS713VvQvQZOxyWNS_Fhx3AbyWX2MvJuVYwwH84X4WiPSjrWVUV1ssvJNrC0bVhneFZERde4pZc3pimE_4Hi3",
#                     "width": 4608
#                 }
#             ],
#             "place_id": "ChIJNwC6xWNYxz4R_nqilTCNDyU",
#             "plus_code": {
#                 "compound_code": "2345+68 Turbat, Pakistan",
#                 "global_code": "7JR52345+68"
#             },
#             "rating": 3.9,
#             "reference": "ChIJNwC6xWNYxz4R_nqilTCNDyU",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 163,
#             "vicinity": "Main Road, Turbat"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 25.9918247,
#                     "lng": 63.0610809
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 25.9930982802915,
#                         "lng": 63.0624188302915
#                     },
#                     "southwest": {
#                         "lat": 25.9904003197085,
#                         "lng": 63.05972086970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Circuit House Turbat",
#             "photos": [
#                 {
#                     "height": 4608,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116596070063656693521\">Naveed Khan Kakar</a>"
#                     ],
#                     "photo_reference": "Aap_uEAbWY_W1DwoMoy5julvQVDwKt_UMRTShPYZzBohlHkQoA9GJatQi1qSxBs2E4tlzh8ltZMNGExeJ0-ai6fFCVGRghQp61vc8U0NTsR4CzAUYtyd5Wo4VIMAAsOJ5GfQ8r1H8C_8NPIme4ifOh3RA-8EVDpm6YOA3UGMIiKwjeKRcEGK",
#                     "width": 3456
#                 }
#             ],
#             "place_id": "ChIJI8FJV9dZxz4RKUKjDCgwL-c",
#             "plus_code": {
#                 "compound_code": "X3R6+PC Turbat, Pakistan",
#                 "global_code": "7JQ5X3R6+PC"
#             },
#             "rating": 4.3,
#             "reference": "ChIJI8FJV9dZxz4RKUKjDCgwL-c",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 18,
#             "vicinity": "College Road, Turbat"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 26.0053047,
#                     "lng": 63.0234815
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 26.0066202302915,
#                         "lng": 63.02477778029151
#                     },
#                     "southwest": {
#                         "lat": 26.0039222697085,
#                         "lng": 63.02207981970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Khand a Hotel",
#             "place_id": "ChIJg2GThHdZxz4R-M5nKjirn34",
#             "rating": 5,
#             "reference": "ChIJg2GThHdZxz4R-M5nKjirn34",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "224F+49H, Turbat"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 26.0037589,
#                     "lng": 63.06587330000001
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 26.0050997802915,
#                         "lng": 63.06703943029151
#                     },
#                     "southwest": {
#                         "lat": 26.0024018197085,
#                         "lng": 63.0643414697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Park Hotel",
#             "photos": [
#                 {
#                     "height": 293,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116653312463460455533\">x BaLusHi</a>"
#                     ],
#                     "photo_reference": "Aap_uEAZqlcp6bb3vCM02pBTm6wBPQ1VmdD055RXPGGMFPtZCLFi6t50g0gVAu5r99Je-n31YJUaz3M0atgKTonNV5BXO9kVdngVVVCA8E-pzCiyLa8wb85GD_Z6sM9S5FTQ4y06RpbDdU1t9fIH0MyuJdFdbRCYhgVfHBYsnNLRkBNI0f9B",
#                     "width": 400
#                 }
#             ],
#             "place_id": "ChIJyxfJk4hYxz4R_hEC8qhRQPI",
#             "plus_code": {
#                 "compound_code": "2338+G8 Turbat, Pakistan",
#                 "global_code": "7JR52338+G8"
#             },
#             "rating": 3.4,
#             "reference": "ChIJyxfJk4hYxz4R_hEC8qhRQPI",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 49,
#             "vicinity": "Commissionery Road, Turbat"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 26.0017799,
#                     "lng": 63.06681880000001
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 26.0031091802915,
#                         "lng": 63.06817618029151
#                     },
#                     "southwest": {
#                         "lat": 26.0004112197085,
#                         "lng": 63.0654782197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "BOQs",
#             "place_id": "ChIJKfJ8JORZxz4RrGtz_Lp7pnk",
#             "plus_code": {
#                 "compound_code": "2328+PP Turbat, Pakistan",
#                 "global_code": "7JR52328+PP"
#             },
#             "reference": "ChIJKfJ8JORZxz4RrGtz_Lp7pnk",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Commissionery Road, Turbat"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 25.9987083,
#                     "lng": 63.06654889999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 26.0000598802915,
#                         "lng": 63.0679010302915
#                     },
#                     "southwest": {
#                         "lat": 25.99736191970849,
#                         "lng": 63.0652030697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Guest Rooms",
#             "place_id": "ChIJEaY0niZZxz4Rq3SV7xIfS_k",
#             "reference": "ChIJEaY0niZZxz4Rq3SV7xIfS_k",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "X3X8+FJM, Turbat"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 25.9984265,
#                     "lng": 63.0665288
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 25.9997543802915,
#                         "lng": 63.0675808302915
#                     },
#                     "southwest": {
#                         "lat": 25.9970564197085,
#                         "lng": 63.06488286970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "MOQ Block",
#             "place_id": "ChIJAVp0-3RZxz4RIcj4gyPg-Lw",
#             "plus_code": {
#                 "compound_code": "X3X8+9J Turbat, Pakistan",
#                 "global_code": "7JQ5X3X8+9J"
#             },
#             "reference": "ChIJAVp0-3RZxz4RIcj4gyPg-Lw",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Commissionery Road, Turbat"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 25.9997347,
#                     "lng": 63.0684626
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 26.0010920802915,
#                         "lng": 63.06969033029151
#                     },
#                     "southwest": {
#                         "lat": 25.9983941197085,
#                         "lng": 63.0669923697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Mess BOQs",
#             "place_id": "ChIJxwVEDSxZxz4RScv1TT7UpxY",
#             "plus_code": {
#                 "compound_code": "X3X9+V9 Turbat, Pakistan",
#                 "global_code": "7JQ5X3X9+V9"
#             },
#             "reference": "ChIJxwVEDSxZxz4RScv1TT7UpxY",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Commissionery Road, Turbat"
#         }
#     ],
#     "status": "OK"
# }
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 29.0323548,
#                     "lng": 21.5496655
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.03371048029149,
#                         "lng": 21.55106433029151
#                     },
#                     "southwest": {
#                         "lat": 29.03101251970849,
#                         "lng": 21.5483663697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "\u0635\u0627\u062d\u0628\u0629 \u0627\u0644\u0641\u062e\u0627\u0645\u0629",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 668,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100198257549635185250\">man asada</a>"
#                     ],
#                     "photo_reference": "Aap_uEDqRytxzk8So7vyppGQnJ75NLR-cD1xQbrEtzb9FuO1-0I2e23NHQFOwIDt4rn04D2ZUQBHiG5EfvsXRwn-tsRGVw5HNrUe9BxqDeL-0TH-99yrm0pZn95qyPCPtKS8vDkIxoOJCVOZ0TXpP4QUzjxvHavj6FTECP7xEDFsR2AH5GFV",
#                     "width": 708
#                 }
#             ],
#             "place_id": "ChIJwzDLJHsfiRMRfChlEnwo9Qw",
#             "plus_code": {
#                 "compound_code": "2GJX+WV Jalu, Libya",
#                 "global_code": "7GX32GJX+WV"
#             },
#             "reference": "ChIJwzDLJHsfiRMRfChlEnwo9Qw",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "\u0627\u0644\u0628\u0644\u0627\u062f\u060c, Jalu"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 29.03272369999999,
#                     "lng": 21.5458054
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.0341612802915,
#                         "lng": 21.5470538302915
#                     },
#                     "southwest": {
#                         "lat": 29.0314633197085,
#                         "lng": 21.54435586970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Jalu Hotel",
#             "photos": [
#                 {
#                     "height": 549,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112139596523063101977\">hemo alhdad</a>"
#                     ],
#                     "photo_reference": "Aap_uEB1zZYdyyTzcwosikzMJysLP1G3nKf0zwB1d7u94M4s47J_UhOavLXN5cVk0gXEKuXRv8nszvEgb15nJtOLGqLdwerT_wl0itV-gfmS1PH_u0a43fzlIgXeRaq79E4ePZxuQgJnay3sHE7t83UUej4UzOVhviyGTD0RuajnocFRWUBV",
#                     "width": 960
#                 }
#             ],
#             "place_id": "ChIJwb2UHcAeiRMRyNRkWbMkgeo",
#             "rating": 3.7,
#             "reference": "ChIJwb2UHcAeiRMRyNRkWbMkgeo",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 148,
#             "vicinity": "2GMW+38M, Jalu"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 29.0398126,
#                     "lng": 21.5353298
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.0411661302915,
#                         "lng": 21.5365794302915
#                     },
#                     "southwest": {
#                         "lat": 29.0384681697085,
#                         "lng": 21.5338814697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Thuraya Tourist Hotel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 405,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111765613585586198436\">\u0637\u0627\u0631\u0642 \u0632\u064a\u0627\u062f \u0627\u0644\u0639\u064a\u0634</a>"
#                     ],
#                     "photo_reference": "Aap_uEBXv4pSPla9flEJYv_vJzlQ6MwMeFxY428NY56UCp7IhX8zOyPRqp0Kh6ZDz4N1JJQBGoy8CK3jCWwBidC_Uw3waODsTQ_7lSi4pGUz9V5ONxsdoatb5dzbLIh-KDHk-qdEOb91eNccLIvgARSR69czOxBTd5g488Y_b6ffmVc3ZlR_",
#                     "width": 720
#                 }
#             ],
#             "place_id": "ChIJd2o5rOgeiRMR3ALID51m3Ow",
#             "rating": 3.8,
#             "reference": "ChIJd2o5rOgeiRMR3ALID51m3Ow",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 142,
#             "vicinity": "2GQP+W4G, Jalu"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 29.0532871,
#                     "lng": 21.5372355
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.0547719302915,
#                         "lng": 21.5383667802915
#                     },
#                     "southwest": {
#                         "lat": 29.0520739697085,
#                         "lng": 21.5356688197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "\u0625\u0633\u062a\u0631\u0627\u062d\u0629 \u0635\u0644\u0627\u062d \u0627\u0644\u0635\u0627\u062f\u0642",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100895415731769728179\">Ahmad Almajbry</a>"
#                     ],
#                     "photo_reference": "Aap_uEAIghKsddUKsOqtXeO5zIr572m3OQKFyb1GMRMgd1y0JBKHgyDfEONGXYVesVOBJg_CoRqfnQjHP6mjLK5ZDX-SLbNTRoWJOzxc1o1Ixgv3ikCJSH8k3JaTM7VAhynVqFrgYIKg_GSB7KVgHG7_uAH68OkySznNx18pG6ShDxZH3Ss5",
#                     "width": 4000
#                 }
#             ],
#             "place_id": "ChIJO-xWCGMfiRMRQ7IZ3IWLNgA",
#             "plus_code": {
#                 "compound_code": "3G3P+8V Jalu, Libya",
#                 "global_code": "7GX33G3P+8V"
#             },
#             "rating": 3.7,
#             "reference": "ChIJO-xWCGMfiRMRQ7IZ3IWLNgA",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 3,
#             "vicinity": "Unnamed Road, \u062c\u0627\u0644\u0648"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 29.0406315,
#                     "lng": 21.4991357
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.04626865,
#                         "lng": 21.50237525
#                     },
#                     "southwest": {
#                         "lat": 29.03875245,
#                         "lng": 21.49805585000001
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "\u0627\u0644\u0628\u064a\u062a \u0627\u0644\u0648\u0638\u064a\u0641\u064a \u062c\u0627\u0644\u0648",
#             "place_id": "ChIJPYji-MwfiRMRfwJdHnfWYDc",
#             "reference": "ChIJPYji-MwfiRMRfwJdHnfWYDc",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "2FRX+7M2, \u062c\u0627\u0644\u0648\u060c"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 29.040621,
#                     "lng": 21.4991334
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.0462739,
#                         "lng": 21.50237639999999
#                     },
#                     "southwest": {
#                         "lat": 29.0387367,
#                         "lng": 21.49805240000001
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Dr. Mohsen Villa",
#             "place_id": "ChIJI0xj9nMfiRMRRoGJxXHnuV4",
#             "reference": "ChIJI0xj9nMfiRMRRoGJxXHnuV4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "2FRX+6MR, Jalu"
#         }
#     ],
#     "status": "OK"
# }
# {
#     "html_attributions": [],
#     "next_page_token": "Aap_uEDvFcSFMkhZEl23mq1j3sRPeJLeQ3nGa_vsXFqqyfvZ9ACU85OFW6vX3TevRMe9dAJwCNRybY9U4dau8ZdDuVOfVvdN47izQ0YHoX84RKyLFIDuUTqx5NKAnw8Ul5g5Ain8fi5Q7dqSBTVpkyXS4bkcrPS7cldOXDwYSuc9w8R8_1PorCVXeCu1BAfUgItjmfGtkfsad-FPIM5LRXGe7OaO3fuIsNymw5E-GDAwWsNWgnWWyRK0Z66EBDGjjjbnPUzGM3554RtjeOWOkVo1RvQke1Iv7eJZlSAWwdihuu7GwN0a-3QrErZCnGBFujZ8KL7IcFiuLGJgE7YJ6ntuZDTCGEQeIIAfy_e2RVUeuRyA31b1i4yOIv-13guJJr6zDJAREErsBBbyVU4InqJzXdeA_YjQTD3xwVV6oyA2RNpJ8jeHt7NZoJoP",
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -21.3403342,
#                     "lng": 55.4727123
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -21.3390070697085,
#                         "lng": 55.47413358029149
#                     },
#                     "southwest": {
#                         "lat": -21.3417050302915,
#                         "lng": 55.47143561970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Lindsey H\u00f4tel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 826,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109032833275752626248\">Lindsey H\u00f4tel</a>"
#                     ],
#                     "photo_reference": "Aap_uECchRVnYyqnE7n93SWeL3xxulZ1Nbf92rekS6s58fvPzhflsSx3TqBw4e6c6z72hJw1UV6zcJpggLns9YbUmqjr8Wa9tDu_fYXeDF9AJD6vbzfmZhGlAl0z1YnW21ucXirLrV1RYEsPIngLlLP1oHR_g2knaKQD2ZDNpvUbDyLOoaHj",
#                     "width": 1181
#                 }
#             ],
#             "place_id": "ChIJI6Tjj7aggiERsLew4oUmhSE",
#             "plus_code": {
#                 "compound_code": "MF5F+V3 Saint Pierre, R\u00e9union",
#                 "global_code": "5HCQMF5F+V3"
#             },
#             "rating": 4.1,
#             "reference": "ChIJI6Tjj7aggiERsLew4oUmhSE",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 113,
#             "vicinity": "21 bis Rue Francois Isautier, Saint-Pierre"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -21.3262465,
#                     "lng": 55.49779770000001
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -21.3249334697085,
#                         "lng": 55.49919688029151
#                     },
#                     "southwest": {
#                         "lat": -21.3276314302915,
#                         "lng": 55.49649891970851
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Villa Belza",
#             "photos": [
#                 {
#                     "height": 6944,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114965217928229157237\">tgspicture photographe</a>"
#                     ],
#                     "photo_reference": "Aap_uEDaSjGzb4V5AcHlLnD5Bs2VbdMLOsLvZ8SVmfMGfljFou5fbtu3zAymJC06iscfXeTIaE1lF1ec6stuUqIssbYleZlfxpeLvijqVq3C_zzF2NOZgKIYNlg5fda3CDXYoEzhE7DZQI6Md7icfzLkkQb67qEN1OA5CQLIKrsOdH5anCYg",
#                     "width": 9280
#                 }
#             ],
#             "place_id": "ChIJE9R__HMKeCERLyMMpy9ZZOw",
#             "plus_code": {
#                 "compound_code": "MFFX+G4 Saint Pierre, R\u00e9union",
#                 "global_code": "5HCQMFFX+G4"
#             },
#             "rating": 4.9,
#             "reference": "ChIJE9R__HMKeCERLyMMpy9ZZOw",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 31,
#             "vicinity": "15A Chemin Bassin Martin"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -21.3438661,
#                     "lng": 55.50358319999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -21.3425413697085,
#                         "lng": 55.50496958029149
#                     },
#                     "southwest": {
#                         "lat": -21.3452393302915,
#                         "lng": 55.50227161970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "L'Oasis de Terre Rouge",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 534,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103508666396900034487\">L&#39;Oasis de Terre Rouge</a>"
#                     ],
#                     "photo_reference": "Aap_uEDOx-qZokDGWM7bcMoBh7AwzjkzfFBHeooHcIi8VoK_M4M3bmkvthHV6rVrFkPR2TTdb7sizRBZkDOBdEgcqVqj6b-XkL_81II8h2EqS9ReIruaSGI7Ebtl7xHYIvhFQzg3-ORXzrQRuLYR-wSVP63qRJwSnw3o3wGqpoHqBozpvRFM",
#                     "width": 800
#                 }
#             ],
#             "place_id": "ChIJpyIktQQKeCERvTuuIdjIx_A",
#             "plus_code": {
#                 "global_code": "5HCQMG43+FC"
#             },
#             "rating": 4.6,
#             "reference": "ChIJpyIktQQKeCERvTuuIdjIx_A",
#             "scope": "GOOGLE",
#             "types": [
#                 "campground",
#                 "lodging",
#                 "park",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 19,
#             "vicinity": "41 Chemin Mezino, Saint-Pierre"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -21.348634,
#                     "lng": 55.48526
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -21.34727081970849,
#                         "lng": 55.4865622802915
#                     },
#                     "southwest": {
#                         "lat": -21.3499687802915,
#                         "lng": 55.4838643197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
# ...
#             "user_ratings_total": 111,
#             "vicinity": "1 Strehlow Street, The Gap"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -23.7029993,
#                     "lng": 133.8864972
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -23.7018228697085,
#                         "lng": 133.8878520802915
#                     },
#                     "southwest": {
#                         "lat": -23.7045208302915,
#                         "lng": 133.8851541197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Mercure Alice Springs Resort",
#             "photos": [
#                 {
#                     "height": 407,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101222648417587538710\">Mercure Alice Springs Resort</a>"
#                     ],
#                     "photo_reference": "Aap_uEA-IwbAkNIKHNtR_23Fq63_tGEeV4bQE0OV-UIrqx4-U-I-q0e0biO3wsJuJx_K66HAlVM7RL_3xTAW5ysVbkdmyBW-_Jp1BI2XlxZBhV7zharGnwJhuGC0Hx-AX2rMTi1wE3IT6ULZ-NYMgR9eJnwRtrsu6DipRgsCfnJLbZ_AS52K",
#                     "width": 612
#                 }
#             ],
#             "place_id": "ChIJ5eZR-F0ZMisRVA-5fOcRwHQ",
#             "plus_code": {
#                 "compound_code": "7VWP+RH Alice Springs NT, Australia",
#                 "global_code": "5Q8M7VWP+RH"
#             },
#             "rating": 4.2,
#             "reference": "ChIJ5eZR-F0ZMisRVA-5fOcRwHQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 601,
#             "vicinity": "34 Stott Terrace, Alice Springs"
#         },
#         {
#             "business_status": "CLOSED_TEMPORARILY",
#             "geometry": {
#                 "location": {
#                     "lat": -23.702275,
#                     "lng": 133.873068
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -23.7006433197085,
#                         "lng": 133.8744236802915
#                     },
#                     "southwest": {
#                         "lat": -23.7033412802915,
#                         "lng": 133.8717257197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Haven Backpacker Resort",
#             "permanently_closed": true,
#             "photos": [
#                 {
#                     "height": 1365,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109775879790765951186\">Haven Backpacker Resort</a>"
#                     ],
#                     "photo_reference": "Aap_uEBpaBe8D239dN7_Xr2bBE3CaKp5GAsbdLDzdpcYfKRAe0O4XuNeJldbVqj6WCcbLWpl-GHwV4553k5HoYctxIaxfWTG8f1bSANAkjICL7ujAiRuTG9xTiE1QzGeGXRfEMmpL_T90PxCkHQ4qt5dDRScJiiTDRmFghqgArWhXaZ1SUIv",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJD86lFU4ZMisRVdQeTh9hbT4",
#             "plus_code": {
#                 "compound_code": "7VXF+36 Alice Springs NT, Australia",
#                 "global_code": "5Q8M7VXF+36"
#             },
#             "rating": 3.6,
#             "reference": "ChIJD86lFU4ZMisRVdQeTh9hbT4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 163,
#             "vicinity": "3 Larapinta Drive, Alice Springs"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -23.7020832,
#                     "lng": 133.8873422
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -23.7007755197085,
#                         "lng": 133.8887698802915
#                     },
#                     "southwest": {
#                         "lat": -23.7034734802915,
#                         "lng": 133.8860719197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Alice's Secret Travellers Inn",
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113530499194276756389\">Reed Hsueh</a>"
#                     ],
#                     "photo_reference": "Aap_uEDzj1KKt38N-kz62VYBFmvocndmGo5eav0LlXGIJOSsseYYKWrnLmHNXSZq9svJ86SlNUaJqB0uYdFL9hRFR9UvDrygo2GiG1ctb7G9s1XeOGkTWRm7HoKIOTyHWniA1d7xldETm6oXmTRWzoxqYW7a9BiB0Yz8rD3Pm6qpPXR3ts0",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJzWJ8Q2cZMisRnnZVMd0zuVM",
#             "plus_code": {
#                 "compound_code": "7VXP+5W East Side NT, Australia",
#                 "global_code": "5Q8M7VXP+5W"
#             },
#             "rating": 4.7,
#             "reference": "ChIJzWJ8Q2cZMisRnnZVMd0zuVM",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 201,
#             "vicinity": "6 Khalick Street, East Side"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -23.7340174,
#                     "lng": 133.8697473
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -23.7326461697085,
#                         "lng": 133.8710748802915
#                     },
#                     "southwest": {
#                         "lat": -23.7353441302915,
#                         "lng": 133.8683769197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "BIG4 MacDonnell Range Holiday Park",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114393371778088386369\">BIG4 MacDonnell Range Holiday Park</a>"
#                     ],
#                     "photo_reference": "Aap_uEB_RQ0df8vTnjoY-HBi6o1mYLPzaCZvvUDAR2C7R_rE-fOb8jTEQ1GbS9o6Myd1q4dZ0_c2nSUZ8pZbCq0Grcrvj8XVHwfSA6XBxbYdrReelHtMglgAnwgEggjbRZlh88Rvui-tVyotelpLfwRIwaYxQSVZbUbW2Y6Q143DOctlh_C8",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJs1jp34obMisRkqXANwcw30M",
#             "plus_code": {
#                 "compound_code": "7V89+9V Ross NT, Australia",
#                 "global_code": "5Q8M7V89+9V"
#             },
#             "rating": 4.5,
#             "reference": "ChIJs1jp34obMisRkqXANwcw30M",
#             "scope": "GOOGLE",
#             "types": [
#                 "rv_park",
#                 "campground",
#                 "lodging",
#                 "park",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 706,
#             "vicinity": "25 Palm Place, Ross"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -23.6970915,
#                     "lng": 133.8843231
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -23.6957425197085,
#                         "lng": 133.8856720802915
#                     },
#                     "southwest": {
#                         "lat": -23.6984404802915,
#                         "lng": 133.8829741197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png",
#             "icon_background_color": "#FF9E67",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/bar_pinlet",
#             "name": "Todd Tavern",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107162094135049899456\">Hector Glower</a>"
#                     ],
#                     "photo_reference": "Aap_uEBPnTZzIeFMG39vq5w6Kev1HK-QoOUKfVTMqvdZOwjnQVNreSu7YM3HGDjGqfZudks34C-rsmD0RHsw4iTEF-9L_5Lj7KVuD26Nh20m1P4PEq22x-kE9Rz6dMuRVSPq-Ckh1JJv2V2fG1Zm3Bsmp8d163ZMunaij7KVyasgYshrsed7",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJ8Zl_-0IZMisRWs-L_O5OpA4",
#             "plus_code": {
#                 "compound_code": "8V3M+5P Alice Springs NT, Australia",
#                 "global_code": "5Q8M8V3M+5P"
#             },
#             "price_level": 1,
#             "rating": 3.9,
#             "reference": "ChIJ8Zl_-0IZMisRWs-L_O5OpA4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "bar",
#                 "liquor_store",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 298,
#             "vicinity": "1 Todd Street, Alice Springs"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -23.716262,
#                     "lng": 133.8730009
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -23.71486661970849,
#                         "lng": 133.8742761802915
#                     },
#                     "southwest": {
#                         "lat": -23.7175645802915,
#                         "lng": 133.8715782197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Swagmans Rest Apartments The",
#             "photos": [
#                 {
#                     "height": 3168,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107760410636014044131\">\u0412\u043b\u0430\u0434 \u041d</a>"
#                     ],
#                     "photo_reference": "Aap_uEAcYPMuRAmGdOuoJajWkKYLnKxZCAW0mWd_AEMOgfMYXwjua3qIorfd0QmsK3hBKPLebFyGzNQb83CKiTpWaJg4ur0vDSsOl_1MlXVHXSE80e0YxujUFVjNR0fRaSZtIpwr9LcjLTpar4KHRcLu_4emNaBYGjB6dWKlrXq9qV6zI4Y",
#                     "width": 5220
#                 }
#             ],
#             "place_id": "ChIJF5GpIvwbMisRezQWvGh4a5o",
#             "plus_code": {
#                 "compound_code": "7VMF+F6 Alice Springs NT, Australia",
#                 "global_code": "5Q8M7VMF+F6"
#             },
#             "rating": 4,
#             "reference": "ChIJF5GpIvwbMisRezQWvGh4a5o",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 30,
#             "vicinity": "67 Gap Road, Alice Springs"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -23.6756936,
#                     "lng": 133.8612398
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -23.67425151970849,
#                         "lng": 133.8626239802915
#                     },
#                     "southwest": {
#                         "lat": -23.6769494802915,
#                         "lng": 133.8599260197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Wilmots on Dixon",
#             "photos": [
#                 {
#                     "height": 2970,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110246046386508780531\">Tim Ware</a>"
#                     ],
#                     "photo_reference": "Aap_uEBQhUKg_zz6tJHGSrFK_JpnsZF0wObR1pKLz0E0lj1ABnncv1FNMBR1Xbb5BJ10GQqOii5hjJ24RZv03wqds_KPY5Hq787QBD2VC75iW1Xex7HmkWdv-8904cN9Dfab3nqbhEMxyAvRPiDb47ziphQGyPhOk0xEt5Sx04VmO6tTZhcO",
#                     "width": 3875
#                 }
#             ],
#             "place_id": "ChIJQX6GFCkfMisRF8fAQkTk2YA",
#             "plus_code": {
#                 "compound_code": "8VF6+PF Alice Springs NT, Australia",
#                 "global_code": "5Q8M8VF6+PF"
#             },
#             "rating": 4.6,
#             "reference": "ChIJQX6GFCkfMisRF8fAQkTk2YA",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 14,
#             "vicinity": "111 Dixon Road, Alice Springs"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -23.6897701,
#                     "lng": 133.8923322
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -23.6884905197085,
#                         "lng": 133.8936670802915
#                     },
#                     "southwest": {
#                         "lat": -23.6911884802915,
#                         "lng": 133.8909691197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Fab Fifties Gem",
#             "place_id": "ChIJz83dZ2wZMisRBVkq7AOyRrU",
#             "plus_code": {
#                 "compound_code": "8V6R+3W Alice Springs NT, Australia",
#                 "global_code": "5Q8M8V6R+3W"
#             },
#             "rating": 1,
#             "reference": "ChIJz83dZ2wZMisRBVkq7AOyRrU",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "45 Giles Street, Alice Springs"
#         }
#     ],
#     "status": "OK"
# }

# %%
hotel_df
# Out:
#                               City      Lat       Lng  Max Temp  Humidity  \
# 71                          Turbat  26.0023   63.0440     76.41        17
# 100                           Jalu  29.0331   21.5482     73.45        35
# 101                   Saint Pierre -21.3393   55.4781     72.93        83
# 158                        Bankura  23.2500   87.0667     72.77        70
# 164                        Baghdad  33.3406   44.4009     71.51        28
# 177                         Ishaqi  34.0164   44.1453     73.13        21
# 190  4699 Old Seale Highway, Seale  32.3502  -85.1999     77.70        55
# 274                     Kiryat Gat  31.6100   34.7642     70.72        67
# 286                       Eldorado -23.7869  -54.2836     79.30        59
# 371                      Jebiniana  35.0350   10.9081     73.20        77
# 536                      Mamoudzou -12.7887   45.2699     75.09        83
# 560                  Alice Springs -23.7000  133.8833     72.95        27
#
#      Cloudiness  Wind Speed Country        Date                  Hotel Name
# 71            0        7.52      PK  1634932688           Mubashar Quarters
# 100           0        9.04      LY  1634932645               صاحبة الفخامة
# 101           0        4.61      RE  1634932697               Lindsey Hôtel
# 158           0        4.29      IN  1634932714          Hotel Priyadarsini
# 164           0        5.75      IQ  1634932716               Baghdad Hotel
# 177           0        9.44      IQ  1634932719                 رضاوي زنوبة
# 190           0        8.55     2.6  1634932724                        Macs
# 274           0        7.38      IL  1634932750                    OlusHome
# 286           0        5.26      BR  1634932754           Villa Verde Hotel
# 371           0        8.12      TN  1634932780           maison belmabrouk
# 536           0        3.44      YT  1634932842                   Le Rocher
# 560           0        8.05      AU  1634932681  Desert Palms Alice Springs

# %%
info_box_content = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
hotel_info = [info_box_content.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]
markerLayermap = hotel_df["Humidity"].astype(float)

# Create a marker_layer using the poverty list to fill the info box
fig = gmaps.figure(center=(0.1, 12.0), zoom_level=2)

heat_layer = gmaps.heatmap_layer(locations, weights=markerLayermap, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 1)

markers = gmaps.marker_layer(marker_locations,
    info_box_content=hotel_info)

fig.add_layer(markers)
fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map


# Display figure

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map


# Display figure
